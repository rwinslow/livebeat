# %%
import cv2
import numpy as np
from PIL import Image, ImageFilter
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('status_unchanged.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.plot(hist)

# %%
img = cv2.imread('status_changed.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.plot(hist)

# %%
img = cv2.imread('status_changed_less_blue.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.plot(hist)

# %%
img = cv2.imread('life_full.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.figure(figsize=(18,2))
plt.plot(hist)
plt.xticks(np.arange(0, 100,5))
plt.xlim((0, 100))
# Out:
# (0, 100)

# %%
img = cv2.imread('all_dead.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.figure(figsize=(18,2))
plt.plot(hist)
plt.xticks(np.arange(0, 100,5))
plt.xlim((0, 100))
# Out:
# (0, 100)

# %%
img = cv2.imread('pixel_life.png')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.figure(figsize=(18,2))
plt.plot(hist)
plt.xticks(np.arange(0, 100,5))
plt.xlim((0, 100))
# Out:
# (0, 100)

# %%
print(sum(hist[0:12]), sum(hist[55:65]))
# Out:
# [ 213.] [ 212.]

# %%
img = cv2.imread('full_screen.png', cv2.IMREAD_UNCHANGED)
img = img[:,:,::-1] # OpenCV BGR -> RGB

h, w, c = img.shape

# Player status
factor = 0.226
y1 = int(h * 0.044)
x1 = int(w * (0.5 - factor))
y2 = y1+1
x2 = int(w * (0.5 + factor))
pl_status = img[y1:y2, x1:x2, :]

# Block out center of player status
h, w, c = pl_status.shape
factor = .12
x1 = int(np.round(w * (0.5 - factor)))+1
x2 = int(np.round(w * (0.5 + factor)))
pl_status[:, x1:x2, :] = 0

plt.figure(figsize=(16,2))
plt.imshow(pl_status)

img = pl_status[:,:,::-1] # Put player status from RGB to BGR for OpenCV
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [0], None, [256], [0,256])
hist[0] = 0
plt.figure(figsize=(18,2))
plt.plot(hist)
plt.xticks(np.arange(0, 100,5))
plt.xlim((0, 100))

print(sum(hist[0:12]), sum(hist[55:65]))
# Out:
# [ 219.] [ 214.]

# %%
img = cv2.imread('full_screen.png', cv2.IMREAD_UNCHANGED)
img = img[:,:,::-1] # OpenCV BGR -> RGB

h, w, c = img.shape

# Player status
factor = 0.226
y1 = int(h * 0.044)
x1 = int(w * (0.5 - factor))
y2 = y1+1
x2 = int(w * (0.5 + factor))
pl_status = img[y1:y2, x1:x2, :]

# Block out center of player status
h, w, c = pl_status.shape
factor = .12
x1 = int(np.round(w * (0.5 - factor)))+1
x2 = int(np.round(w * (0.5 + factor)))
pl_status[:, x1:x2, :] = 0

plt.figure(figsize=(16,2))
plt.imshow(pl_status)

img = pl_status[:,:,::-1] # Put player status from RGB to BGR for OpenCV
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([hsv], [1], None, [256], [0,256])
hist[0] = 0
plt.figure(figsize=(18,2))
plt.plot(hist)
plt.xticks(np.arange(0, 100,5))
plt.xlim((0, 100))

print(sum(hist[0:12]), sum(hist[55:65]))
# Out:
# [ 358.] [ 214.]
